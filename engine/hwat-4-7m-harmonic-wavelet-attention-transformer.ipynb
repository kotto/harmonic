# %% [markdown]
# # 🌊 HWAT 4.7M — Harmonic Wavelet Attention Transformer
# ## Entraînement sur Kaggle GPU (P100 gratuit)
#
# Modèle : 4.7M params, dim=256, 4 couches, 4 têtes
# Données : 100K exemples structurés (synonymes + relations)
# Durée estimée : ~5-10 minutes sur GPU

# %%
import math, time, random, os
from pathlib import Path
from collections import Counter
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('='*60)
print('  🌊 HWAT Training — Kaggle GPU')
print(f'  Device: {device}')
if torch.cuda.is_available():
    print(f'  GPU: {torch.cuda.get_device_name(0)}')
    print(f'  VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
    # !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader
print('='*60)
# Out:
# ============================================================
#   🌊 HWAT Training — Kaggle GPU
#   Device: cpu
# ============================================================

# %%
# ═══════════════════════════════════════════════════════════
# CONSTANTES & UTILITAIRES
# ═══════════════════════════════════════════════════════════

PHI = 1.618033988749895
ALPHA = 1.0 / PHI
TAU = 2.0 * math.pi

def _fnv1a(s: str) -> int:
    h = 2166136261
    for ch in s.encode('utf-8'):
        h ^= ch; h = (h * 16777619) & 0xFFFFFFFF
    return h

# ═══════════════════════════════════════════════════════════
# PHASE ATTENTION (optimisée, GPU-ready)
# ═══════════════════════════════════════════════════════════

def phase_attention(psi, n_heads, causal=True):
    L, D = psi.shape
    head_dim = D // n_heads
    heads = psi.reshape(L, n_heads, head_dim).permute(1, 0, 2)
    H, L, d = heads.shape
    
    A = heads.abs().float()
    phi = heads.angle().float()
    cos_phi = torch.cos(phi)
    sin_phi = torch.sin(phi)
    
    # cos(φ_i - φ_j) = cos(φ_i)cos(φ_j) + sin(φ_i)sin(φ_j)
    phase_scores = (cos_phi @ cos_phi.transpose(1,2) + sin_phi @ sin_phi.transpose(1,2)) / d
    A_norm_sq = (A**2).sum(dim=-1)
    amp_scores = torch.sqrt(torch.clamp(A_norm_sq.unsqueeze(2)*A_norm_sq.unsqueeze(1), min=1e-10))
    scores = phase_scores * amp_scores
    
    if causal:
        mask = torch.triu(torch.ones(L, L, device=psi.device, dtype=torch.float32), diagonal=1)
        scores = scores - 1e9 * mask.unsqueeze(0)
    
    scores = scores - scores.max(dim=-1, keepdim=True).values
    attn = torch.softmax(scores.double(), dim=-1).float()
    out = attn.to(heads.dtype) @ heads
    return out.permute(1, 0, 2).reshape(L, D).to(psi.dtype)

# %%
# ═══════════════════════════════════════════════════════════
# MLP & LayerNorm
# ═══════════════════════════════════════════════════════════

def mlp(psi, W1, W2, b1=None, b2=None):
    A = psi.abs().float()
    phase = psi.angle().float()
    h = A @ W1
    if b1 is not None: h = h + b1
    h = F.relu(h)
    A_new = h @ W2
    if b2 is not None: A_new = A_new + b2
    return (A_new * (torch.cos(phase) + 1j*torch.sin(phase))).to(psi.dtype)

def layernorm_amp(psi, gamma=None, beta=None, eps=1e-6):
    A = psi.abs()
    mu = A.mean(dim=-1, keepdim=True)
    sigma = A.std(dim=-1, keepdim=True) + eps
    A_norm = (A - mu) / sigma
    if gamma is not None: A_norm = A_norm * gamma
    if beta is not None: A_norm = A_norm + beta
    phase = psi.angle()
    return (A_norm * (torch.cos(phase) + 1j*torch.sin(phase))).to(psi.dtype)

# %%
# ═══════════════════════════════════════════════════════════
# MODÈLE HWAT
# ═══════════════════════════════════════════════════════════

class HWAT(nn.Module):
    def __init__(self, vocab_size, dim=256, n_layers=4, n_heads=4, max_seq_len=64, hidden_mult=4):
        super().__init__()
        self.vocab_size = vocab_size
        self.dim = dim
        self.n_layers = n_layers
        self.n_heads = n_heads
        self.max_seq_len = max_seq_len
        self.hidden_dim = dim * hidden_mult
        self.ctype = torch.complex64

        # Embedding déterministe (buffers = pas de gradient)
        sigma = 1.0 / math.sqrt(dim)
        def det_norm(size, seed):
            g = torch.Generator(); g.manual_seed(seed & 0xFFFFFFFF)
            return torch.randn(size, generator=g, dtype=torch.float32)
        
        A_tab = torch.zeros(vocab_size, dim)
        phi_tok = torch.zeros(vocab_size, dim)
        for tok in range(vocab_size):
            v = det_norm(dim, _fnv1a(f'amp_{tok}')) * sigma
            A_tab[tok] = v / (v.norm() + 1e-30)
            phi_tok[tok] = det_norm(dim, _fnv1a(f'phi_{tok}')).fmod(1.0) * TAU
        
        phi_pos = torch.zeros(max_seq_len, dim)
        ks = torch.arange(dim, dtype=torch.float32) / max(dim-1, 1)
        omegas = 0.1 * torch.pow(torch.tensor(math.pi/0.1), ks)
        for p in range(max_seq_len): phi_pos[p] = omegas * p
        
        self.register_buffer('A_table', A_tab)
        self.register_buffer('phi_token', phi_tok)
        self.register_buffer('phi_pos', phi_pos)

        # Blocs MLP (paramètres entraînables)
        self.W1 = nn.ParameterList()
        self.b1 = nn.ParameterList()
        self.W2 = nn.ParameterList()
        self.b2 = nn.ParameterList()
        self.ln_gamma = nn.ParameterList()
        self.ln_beta = nn.ParameterList()
        
        for lid in range(n_layers):
            H = self.hidden_dim
            D = dim
            g1 = torch.Generator(); g1.manual_seed(_fnv1a(f'mlp_w1_{lid}') & 0xFFFFFFFF)
            g3 = torch.Generator(); g3.manual_seed(_fnv1a(f'mlp_w2_{lid}') & 0xFFFFFFFF)
            lim1 = math.sqrt(3.0/D)
            lim2 = math.sqrt(3.0/H)
            self.W1.append(nn.Parameter(torch.randn(D, H, generator=g1) * 2*lim1 - lim1))
            self.b1.append(nn.Parameter(torch.zeros(H)))
            self.W2.append(nn.Parameter(torch.randn(H, D, generator=g3) * 2*lim2 - lim2))
            self.b2.append(nn.Parameter(torch.zeros(D)))
            self.ln_gamma.append(nn.Parameter(torch.ones(D)))
            self.ln_beta.append(nn.Parameter(torch.zeros(D)))

        # Tête de langage
        g = torch.Generator(); g.manual_seed(_fnv1a('lm_head') & 0xFFFFFFFF)
        self.lm_head = nn.Parameter(torch.randn(2*dim, vocab_size, generator=g) * math.sqrt(2.0/(2*dim)))
        self.lm_bias = nn.Parameter(torch.zeros(vocab_size))

    def embed(self, token_ids):
        L = min(len(token_ids), self.max_seq_len)
        token_ids = token_ids[:L]
        A = self.A_table[token_ids]
        phi_t = self.phi_token[token_ids]
        phi_p = self.phi_pos[:L]
        phi = phi_t + phi_p
        return (A * (torch.cos(phi) + 1j*torch.sin(phi))).to(self.ctype)

    def forward(self, token_ids):
        psi = self.embed(token_ids)
        for li in range(self.n_layers):
            x = layernorm_amp(psi, self.ln_gamma[li], self.ln_beta[li])
            x = phase_attention(x, self.n_heads, causal=True)
            psi = psi + x
            x = layernorm_amp(psi, self.ln_gamma[li], self.ln_beta[li])
            x = mlp(x, self.W1[li], self.W2[li], self.b1[li], self.b2[li])
            psi = psi + x
        psi_flat = torch.cat([psi.real.float(), psi.imag.float()], dim=-1)
        return psi_flat @ self.lm_head + self.lm_bias

print('✅ Modèle HWAT défini')
# Out:
# ✅ Modèle HWAT défini

# %%
# ═══════════════════════════════════════════════════════════
# DONNÉES D'ENTRAÎNEMENT
# ═══════════════════════════════════════════════════════════

print('Génération des données...')
rng = random.Random(42)

syns = [
    ('commencer','debuter'),('terminer','finir'),('rapide','vite'),
    ('lent','ralenti'),('grand','vaste'),('petit','minuscule'),
    ('beau','joli'),('intelligent','brillant'),('fort','puissant'),
    ('heureux','joyeux'),('triste','malheureux'),('faible','fragile'),
    ('begin','start'),('end','finish'),('fast','quick'),('slow','sluggish'),
    ('big','large'),('small','tiny'),('beautiful','pretty'),('smart','clever'),
]
rels = [
    ('Paris','capitale','France'),('Soleil','etoile','chaud'),
    ('eau','liquide','vie'),('Terre','planete','Soleil'),
    ('lumiere','onde','electromagnetique'),('Einstein','decouvert','relativite'),
    ('Newton','formule','lois du mouvement'),('Python','langage','programmation'),
    ('ADN','contient','information genetique'),('coeur','pompe','sang'),
    ('gravite','attire','objets'),('plantes','produisent','oxygene'),
    ('atome','compose','protons neutrons electrons'),('cerveau','traite','information'),
]
templates = [
    '{a} est un synonyme de {b}.', 'Le mot {a} signifie {b}.', '{a} = {b}.',
    '{a} et {b} sont equivalents.', 'On peut dire {a} ou {b}.',
    '{s} {r} {o}.', 'On sait que {s} {r} {o}.', 'C est un fait: {s} {r} {o}.',
    'La science dit: {s} {r} {o}.', 'Il est connu que {s} {r} {o}.',
]

texts = []
for _ in range(100000):
    if rng.random() < 0.6:
        a, b = rng.choice(syns)
        texts.append(rng.choice(templates[:5]).format(a=a, b=b))
    else:
        s, r, o = rng.choice(rels)
        texts.append(rng.choice(templates[5:]).format(s=s, r=r, o=o))
rng.shuffle(texts)

VOCAB_SIZE = 5000
MAX_LEN = 64
wc = Counter()
for t in texts: wc.update(t.lower().split())
w2i = {'<pad>':0, '<unk>':1, '<s>':2, '</s>':3}
for w, _ in wc.most_common(VOCAB_SIZE-4):
    w2i[w] = len(w2i)
i2w = {v:k for k,v in w2i.items()}
seqs = [[2] + [w2i.get(w,1) for w in t.lower().split()[:MAX_LEN-2]] + [3] for t in texts]

print(f'  {len(seqs):,} séquences, vocab={len(w2i)}')
# Out:
# Génération des données...
#   100,000 séquences, vocab=135

# %%
# ═══════════════════════════════════════════════════════════
# CRÉATION DU MODÈLE
# ═══════════════════════════════════════════════════════════

MODEL_DIM = 256
MODEL_LAYERS = 4
MODEL_HEADS = 4
BATCH_SIZE = 8
EPOCHS = 5
LR = 3e-4

model = HWAT(
    vocab_size=min(len(w2i), VOCAB_SIZE),
    dim=MODEL_DIM, n_layers=MODEL_LAYERS, n_heads=MODEL_HEADS,
    max_seq_len=MAX_LEN, hidden_mult=4
).to(device)

n_params = sum(p.numel() for p in model.parameters())
print(f'Modèle: {n_params:,} paramètres sur {device}')
# Out:
# Modèle: 2,173,575 paramètres sur cpu

# %%
# ═══════════════════════════════════════════════════════════
# ENTRAÎNEMENT
# ═══════════════════════════════════════════════════════════

optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=EPOCHS * len(seqs) // BATCH_SIZE
)

print(f'Entraînement: {EPOCHS} epochs, batch={BATCH_SIZE}')
print(f'Total batches: {len(seqs)//BATCH_SIZE * EPOCHS:,}')
print()

t_start = time.time()
step = 0
best_loss = float('inf')
loss_history = []

for epoch in range(EPOCHS):
    random.shuffle(seqs)
    epoch_loss = 0.0
    n_batches = len(seqs) // BATCH_SIZE
    
    for bi in range(n_batches):
        # ── Batch ──
        batch_seqs = seqs[bi*BATCH_SIZE:(bi+1)*BATCH_SIZE]
        inputs = torch.zeros(BATCH_SIZE, MAX_LEN, dtype=torch.long, device=device)
        targets = torch.zeros(BATCH_SIZE, MAX_LEN, dtype=torch.long, device=device)
        for i, s in enumerate(batch_seqs):
            n = min(len(s), MAX_LEN+1)
            inputs[i, :n-1] = torch.tensor(s[:n-1], device=device)
            targets[i, :n-1] = torch.tensor(s[1:n], device=device)
        
        # ── Forward + Backward ──
        optimizer.zero_grad()
        batch_loss = 0.0
        for b in range(BATCH_SIZE):
            logits = model(inputs[b])
            loss = F.cross_entropy(
                logits.unsqueeze(0).transpose(1, 2),
                targets[b].unsqueeze(0),
                ignore_index=0
            )
            batch_loss += loss
        batch_loss = batch_loss / BATCH_SIZE
        batch_loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        
        epoch_loss += batch_loss.item()
        step += 1
        
        # ── Logging ──
        if step % 200 == 0:
            elapsed = time.time() - t_start
            avg_loss = epoch_loss / (bi + 1)
            loss_history.append((step, avg_loss))
            print(f'  step {step:5d} | loss: {avg_loss:.4f} | '
                  f'{elapsed/60:.0f}min | {step/(elapsed+1e-10):.1f} step/s')
            
            if avg_loss < best_loss:
                best_loss = avg_loss
                torch.save(model.state_dict(), 'model_best.pt')
        
        # ── Checkpoint ──
        if step % 2000 == 0:
            torch.save({
                'step': step, 'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': avg_loss,
            }, f'model_step{step}.pt')
    
    epoch_avg = epoch_loss / max(1, n_batches)
    elapsed = time.time() - t_start
    print(f'  ── Epoch {epoch+1} | avg loss: {epoch_avg:.4f} | {elapsed/60:.0f}min ──')

# ── Final ──
total_time = time.time() - t_start
torch.save(model.state_dict(), 'model_final.pt')
print(f'\n✅ Entraînement terminé')
print(f'   Steps: {step} | Temps: {total_time/60:.0f} min')
print(f'   Steps/sec: {step/total_time:.1f}')
print(f'   Best loss: {best_loss:.4f}')
# Out:
# Entraînement: 5 epochs, batch=8
# Total batches: 62,500
#
#   step   200 | loss: 4.7017 | 1min | 2.3 step/s
#   step   400 | loss: 3.4504 | 3min | 2.4 step/s
#   step   600 | loss: 2.8487 | 4min | 2.3 step/s
#   step   800 | loss: 2.4900 | 6min | 2.3 step/s
#   step  1000 | loss: 2.2564 | 7min | 2.3 step/s
#   step  1200 | loss: 2.0918 | 9min | 2.3 step/s
#   step  1400 | loss: 1.9764 | 10min | 2.3 step/s
#   step  1600 | loss: 1.8849 | 11min | 2.3 step/s
#   step  1800 | loss: 1.8136 | 13min | 2.3 step/s
#   step  2000 | loss: 1.7586 | 14min | 2.3 step/s
#   step  2200 | loss: 1.7120 | 16min | 2.3 step/s
#   step  2400 | loss: 1.6730 | 17min | 2.3 step/s
#   step  2600 | loss: 1.6403 | 18min | 2.3 step/s
#   step  2800 | loss: 1.6113 | 20min | 2.3 step/s
#   step  3000 | loss: 1.5874 | 21min | 2.3 step/s
#   step  3200 | loss: 1.5663 | 23min | 2.3 step/s
#   step  3400 | loss: 1.5460 | 24min | 2.3 step/s
#   step  3600 | loss: 1.5296 | 26min | 2.3 step/s
#   step  3800 | loss: 1.5143 | 27min | 2.3 step/s
#   step  4000 | loss: 1.5000 | 28min | 2.3 step/s
#   step  4200 | loss: 1.4876 | 30min | 2.3 step/s
#   step  4400 | loss: 1.4764 | 31min | 2.3 step/s
#   step  4600 | loss: 1.4665 | 33min | 2.3 step/s
#   step  4800 | loss: 1.4570 | 34min | 2.3 step/s
#   step  5000 | loss: 1.4485 | 36min | 2.3 step/s
#   step  5200 | loss: 1.4405 | 37min | 2.3 step/s
#   step  5400 | loss: 1.4329 | 38min | 2.3 step/s
#   step  5600 | loss: 1.4257 | 40min | 2.3 step/s
#   step  5800 | loss: 1.4193 | 41min | 2.3 step/s
#   step  6000 | loss: 1.4132 | 43min | 2.3 step/s
#   step  6200 | loss: 1.4077 | 44min | 2.3 step/s
#   step  6400 | loss: 1.4023 | 46min | 2.3 step/s
#   step  6600 | loss: 1.3974 | 47min | 2.3 step/s
#   step  6800 | loss: 1.3931 | 49min | 2.3 step/s
#   step  7000 | loss: 1.3888 | 50min | 2.3 step/s
#   step  7200 | loss: 1.3847 | 51min | 2.3 step/s
#   step  7400 | loss: 1.3809 | 53min | 2.3 step/s
#   step  7600 | loss: 1.3769 | 54min | 2.3 step/s
#   step  7800 | loss: 1.3731 | 56min | 2.3 step/s
#   step  8000 | loss: 1.3696 | 57min | 2.3 step/s
#   step  8200 | loss: 1.3670 | 59min | 2.3 step/s
#   step  8400 | loss: 1.3641 | 60min | 2.3 step/s
#   step  8600 | loss: 1.3616 | 62min | 2.3 step/s
#   step  8800 | loss: 1.3585 | 63min | 2.3 step/s
#   step  9000 | loss: 1.3559 | 65min | 2.3 step/s
#   step  9200 | loss: 1.3534 | 66min | 2.3 step/s
#   step  9400 | loss: 1.3512 | 68min | 2.3 step/s
#   step  9600 | loss: 1.3488 | 69min | 2.3 step/s
#   step  9800 | loss: 1.3464 | 70min | 2.3 step/s
#   step 10000 | loss: 1.3442 | 72min | 2.3 step/s
#   step 10200 | loss: 1.3418 | 73min | 2.3 step/s
#   step 10400 | loss: 1.3401 | 75min | 2.3 step/s
#   step 10600 | loss: 1.3382 | 76min | 2.3 step/s
#   step 10800 | loss: 1.3363 | 78min | 2.3 step/s
#   step 11000 | loss: 1.3346 | 79min | 2.3 step/s
#   step 11200 | loss: 1.3326 | 80min | 2.3 step/s
#   step 11400 | loss: 1.3306 | 82min | 2.3 step/s
#   step 11600 | loss: 1.3289 | 83min | 2.3 step/s
#   step 11800 | loss: 1.3269 | 85min | 2.3 step/s
#   step 12000 | loss: 1.3255 | 86min | 2.3 step/s
#   step 12200 | loss: 1.3240 | 88min | 2.3 step/s
#   step 12400 | loss: 1.3223 | 89min | 2.3 step/s
#   ── Epoch 1 | avg loss: 1.3216 | 90min ──
#   step 12600 | loss: 1.2217 | 90min | 2.3 step/s
#   step 12800 | loss: 1.2283 | 92min | 2.3 step/s
#   step 13000 | loss: 1.2293 | 93min | 2.3 step/s
#   step 13200 | loss: 1.2334 | 95min | 2.3 step/s
#   step 13400 | loss: 1.2347 | 96min | 2.3 step/s
#   step 13600 | loss: 1.2302 | 98min | 2.3 step/s
#   step 13800 | loss: 1.2309 | 99min | 2.3 step/s
#   step 14000 | loss: 1.2311 | 100min | 2.3 step/s
#   step 14200 | loss: 1.2312 | 102min | 2.3 step/s
#   step 14400 | loss: 1.2317 | 103min | 2.3 step/s
#   step 14600 | loss: 1.2314 | 105min | 2.3 step/s
#   step 14800 | loss: 1.2313 | 106min | 2.3 step/s
#   step 15000 | loss: 1.2311 | 108min | 2.3 step/s
#   step 15200 | loss: 1.2316 | 109min | 2.3 step/s
#   step 15400 | loss: 1.2310 | 110min | 2.3 step/s
#   step 15600 | loss: 1.2308 | 112min | 2.3 step/s
#   step 15800 | loss: 1.2299 | 113min | 2.3 step/s
#   step 16000 | loss: 1.2301 | 115min | 2.3 step/s
#   step 16200 | loss: 1.2293 | 116min | 2.3 step/s
#   step 16400 | loss: 1.2287 | 118min | 2.3 step/s
#   step 16600 | loss: 1.2292 | 119min | 2.3 step/s
#   step 16800 | loss: 1.2288 | 121min | 2.3 step/s
#   step 17000 | loss: 1.2291 | 122min | 2.3 step/s
#   step 17200 | loss: 1.2291 | 123min | 2.3 step/s
#   step 17400 | loss: 1.2283 | 125min | 2.3 step/s
#   step 17600 | loss: 1.2284 | 126min | 2.3 step/s
#   step 17800 | loss: 1.2283 | 128min | 2.3 step/s
#   step 18000 | loss: 1.2285 | 129min | 2.3 step/s
#   step 18200 | loss: 1.2284 | 131min | 2.3 step/s
#   step 18400 | loss: 1.2283 | 132min | 2.3 step/s
#   step 18600 | loss: 1.2286 | 133min | 2.3 step/s
#   step 18800 | loss: 1.2281 | 135min | 2.3 step/s
#   step 19000 | loss: 1.2283 | 136min | 2.3 step/s
#   step 19200 | loss: 1.2279 | 137min | 2.3 step/s
#   step 19400 | loss: 1.2277 | 139min | 2.3 step/s
#   step 19600 | loss: 1.2276 | 140min | 2.3 step/s
#   step 19800 | loss: 1.2276 | 142min | 2.3 step/s
#   step 20000 | loss: 1.2272 | 143min | 2.3 step/s
#   step 20200 | loss: 1.2266 | 145min | 2.3 step/s
#   step 20400 | loss: 1.2265 | 146min | 2.3 step/s
#   step 20600 | loss: 1.2263 | 147min | 2.3 step/s
#   step 20800 | loss: 1.2259 | 149min | 2.3 step/s
#   step 21000 | loss: 1.2260 | 150min | 2.3 step/s
#   step 21200 | loss: 1.2259 | 152min | 2.3 step/s
#   step 21400 | loss: 1.2253 | 153min | 2.3 step/s
#   step 21600 | loss: 1.2255 | 155min | 2.3 step/s
#   step 21800 | loss: 1.2254 | 156min | 2.3 step/s
#   step 22000 | loss: 1.2251 | 157min | 2.3 step/s
#   step 22200 | loss: 1.2251 | 159min | 2.3 step/s
#   step 22400 | loss: 1.2249 | 160min | 2.3 step/s
#   step 22600 | loss: 1.2248 | 162min | 2.3 step/s
#   step 22800 | loss: 1.2247 | 163min | 2.3 step/s
#   step 23000 | loss: 1.2247 | 164min | 2.3 step/s
#   step 23200 | loss: 1.2247 | 166min | 2.3 step/s
#   step 23400 | loss: 1.2249 | 167min | 2.3 step/s
#   step 23600 | loss: 1.2246 | 169min | 2.3 step/s
#   step 23800 | loss: 1.2247 | 170min | 2.3 step/s
#   step 24000 | loss: 1.2247 | 171min | 2.3 step/s
#   step 24200 | loss: 1.2243 | 173min | 2.3 step/s
#   step 24400 | loss: 1.2245 | 174min | 2.3 step/s
#   step 24600 | loss: 1.2243 | 176min | 2.3 step/s
#   step 24800 | loss: 1.2244 | 177min | 2.3 step/s
#   step 25000 | loss: 1.2243 | 178min | 2.3 step/s
#   ── Epoch 2 | avg loss: 1.2243 | 178min ──
#   step 25200 | loss: 1.2215 | 180min | 2.3 step/s
#   step 25400 | loss: 1.2129 | 181min | 2.3 step/s
#   step 25600 | loss: 1.2106 | 183min | 2.3 step/s
#   step 25800 | loss: 1.2110 | 184min | 2.3 step/s
#   step 26000 | loss: 1.2124 | 186min | 2.3 step/s
#   step 26200 | loss: 1.2090 | 187min | 2.3 step/s
#   step 26400 | loss: 1.2083 | 188min | 2.3 step/s
#   step 26600 | loss: 1.2097 | 190min | 2.3 step/s
#   step 26800 | loss: 1.2105 | 191min | 2.3 step/s
#   step 27000 | loss: 1.2123 | 193min | 2.3 step/s
#   step 27200 | loss: 1.2134 | 194min | 2.3 step/s
#   step 27400 | loss: 1.2141 | 196min | 2.3 step/s
#   step 27600 | loss: 1.2144 | 197min | 2.3 step/s
#   step 27800 | loss: 1.2158 | 198min | 2.3 step/s
#   step 28000 | loss: 1.2161 | 200min | 2.3 step/s
#   step 28200 | loss: 1.2151 | 201min | 2.3 step/s
#   step 28400 | loss: 1.2148 | 203min | 2.3 step/s
#   step 28600 | loss: 1.2148 | 204min | 2.3 step/s
#   step 28800 | loss: 1.2138 | 205min | 2.3 step/s
#   step 29000 | loss: 1.2138 | 207min | 2.3 step/s
#   step 29200 | loss: 1.2139 | 208min | 2.3 step/s
#   step 29400 | loss: 1.2133 | 209min | 2.3 step/s
#   step 29600 | loss: 1.2136 | 211min | 2.3 step/s
#   step 29800 | loss: 1.2133 | 212min | 2.3 step/s
#   step 30000 | loss: 1.2129 | 214min | 2.3 step/s
#   step 30200 | loss: 1.2125 | 215min | 2.3 step/s
#   step 30400 | loss: 1.2122 | 216min | 2.3 step/s
#   step 30600 | loss: 1.2118 | 218min | 2.3 step/s
#   step 30800 | loss: 1.2116 | 219min | 2.3 step/s
#   step 31000 | loss: 1.2126 | 220min | 2.3 step/s
#   step 31200 | loss: 1.2129 | 222min | 2.3 step/s
#   step 31400 | loss: 1.2128 | 223min | 2.3 step/s
#   step 31600 | loss: 1.2127 | 225min | 2.3 step/s
#   step 31800 | loss: 1.2127 | 226min | 2.3 step/s
#   step 32000 | loss: 1.2121 | 228min | 2.3 step/s
#   step 32200 | loss: 1.2118 | 229min | 2.3 step/s
#   step 32400 | loss: 1.2117 | 230min | 2.3 step/s
#   step 32600 | loss: 1.2118 | 232min | 2.3 step/s
#   step 32800 | loss: 1.2118 | 233min | 2.3 step/s
#   step 33000 | loss: 1.2118 | 235min | 2.3 step/s
#   step 33200 | loss: 1.2116 | 236min | 2.3 step/s
#   step 33400 | loss: 1.2112 | 237min | 2.3 step/s
#   step 33600 | loss: 1.2113 | 239min | 2.3 step/s
#   step 33800 | loss: 1.2111 | 240min | 2.3 step/s
#   step 34000 | loss: 1.2109 | 241min | 2.3 step/s
#   step 34200 | loss: 1.2110 | 243min | 2.3 step/s
#   step 34400 | loss: 1.2107 | 244min | 2.3 step/s
#   step 34600 | loss: 1.2108 | 246min | 2.3 step/s
#   step 34800 | loss: 1.2105 | 247min | 2.3 step/s
#   step 35000 | loss: 1.2104 | 248min | 2.3 step/s
#   step 35200 | loss: 1.2105 | 250min | 2.3 step/s
#   step 35400 | loss: 1.2103 | 251min | 2.3 step/s
#   step 35600 | loss: 1.2104 | 253min | 2.3 step/s
#   step 35800 | loss: 1.2102 | 254min | 2.3 step/s
#   step 36000 | loss: 1.2101 | 255min | 2.4 step/s
#   step 36200 | loss: 1.2099 | 257min | 2.4 step/s
#   step 36400 | loss: 1.2101 | 258min | 2.4 step/s
#   step 36600 | loss: 1.2099 | 260min | 2.3 step/s
#   step 36800 | loss: 1.2098 | 261min | 2.4 step/s
#   step 37000 | loss: 1.2098 | 262min | 2.3 step/s
#   step 37200 | loss: 1.2097 | 264min | 2.3 step/s
#   step 37400 | loss: 1.2098 | 265min | 2.3 step/s
#   ── Epoch 3 | avg loss: 1.2098 | 266min ──
#   step 37600 | loss: 1.1875 | 267min | 2.3 step/s
#   step 37800 | loss: 1.1926 | 268min | 2.3 step/s
#   step 38000 | loss: 1.2010 | 270min | 2.3 step/s
#   step 38200 | loss: 1.2052 | 271min | 2.3 step/s
#   step 38400 | loss: 1.2033 | 273min | 2.3 step/s
#   step 38600 | loss: 1.2008 | 274min | 2.3 step/s
#   step 38800 | loss: 1.1990 | 276min | 2.3 step/s
#   step 39000 | loss: 1.2011 | 277min | 2.3 step/s
#   step 39200 | loss: 1.2006 | 279min | 2.3 step/s
#   step 39400 | loss: 1.1999 | 280min | 2.3 step/s
#   step 39600 | loss: 1.1988 | 281min | 2.3 step/s
#   step 39800 | loss: 1.1993 | 283min | 2.3 step/s
#   step 40000 | loss: 1.1984 | 284min | 2.3 step/s
#   step 40200 | loss: 1.2001 | 286min | 2.3 step/s
#   step 40400 | loss: 1.2010 | 287min | 2.3 step/s
#   step 40600 | loss: 1.2016 | 288min | 2.3 step/s
#   step 40800 | loss: 1.2011 | 290min | 2.3 step/s
#   step 41000 | loss: 1.2016 | 291min | 2.3 step/s
#   step 41200 | loss: 1.2013 | 292min | 2.3 step/s
#   step 41400 | loss: 1.2017 | 294min | 2.3 step/s
#   step 41600 | loss: 1.2013 | 295min | 2.3 step/s
#   step 41800 | loss: 1.2016 | 297min | 2.3 step/s
#   step 42000 | loss: 1.2009 | 298min | 2.3 step/s
#   step 42200 | loss: 1.2007 | 299min | 2.3 step/s
#   step 42400 | loss: 1.2011 | 301min | 2.3 step/s
#   step 42600 | loss: 1.2012 | 302min | 2.3 step/s
#   step 42800 | loss: 1.2009 | 304min | 2.3 step/s
#   step 43000 | loss: 1.2009 | 305min | 2.3 step/s
#   step 43200 | loss: 1.2010 | 306min | 2.3 step/s
#   step 43400 | loss: 1.2010 | 308min | 2.3 step/s
#   step 43600 | loss: 1.2008 | 309min | 2.3 step/s
#   step 43800 | loss: 1.2005 | 311min | 2.3 step/s
#   step 44000 | loss: 1.2005 | 312min | 2.4 step/s
#   step 44200 | loss: 1.2009 | 313min | 2.3 step/s
#   step 44400 | loss: 1.2005 | 315min | 2.4 step/s
#   step 44600 | loss: 1.2005 | 316min | 2.4 step/s
#   step 44800 | loss: 1.1999 | 318min | 2.4 step/s
#   step 45000 | loss: 1.1996 | 319min | 2.4 step/s
#   step 45200 | loss: 1.1997 | 320min | 2.4 step/s
#   step 45400 | loss: 1.1999 | 322min | 2.4 step/s
#   step 45600 | loss: 1.1997 | 323min | 2.4 step/s
#   step 45800 | loss: 1.1995 | 325min | 2.4 step/s
#   step 46000 | loss: 1.1993 | 326min | 2.4 step/s
#   step 46200 | loss: 1.1990 | 327min | 2.4 step/s
#   step 46400 | loss: 1.1989 | 329min | 2.4 step/s
#   step 46600 | loss: 1.1989 | 330min | 2.4 step/s
#   step 46800 | loss: 1.1988 | 332min | 2.4 step/s
#   step 47000 | loss: 1.1986 | 333min | 2.4 step/s
#   step 47200 | loss: 1.1985 | 335min | 2.4 step/s
#   step 47400 | loss: 1.1985 | 336min | 2.4 step/s
#   step 47600 | loss: 1.1984 | 337min | 2.4 step/s
#   step 47800 | loss: 1.1983 | 339min | 2.4 step/s
#   step 48000 | loss: 1.1983 | 340min | 2.4 step/s
#   step 48200 | loss: 1.1983 | 342min | 2.4 step/s
#   step 48400 | loss: 1.1981 | 343min | 2.4 step/s
#   step 48600 | loss: 1.1977 | 344min | 2.4 step/s
#   step 48800 | loss: 1.1973 | 346min | 2.4 step/s
#   step 49000 | loss: 1.1975 | 347min | 2.4 step/s
#   step 49200 | loss: 1.1974 | 349min | 2.4 step/s
#   step 49400 | loss: 1.1975 | 350min | 2.4 step/s
#   step 49600 | loss: 1.1975 | 352min | 2.4 step/s
#   step 49800 | loss: 1.1970 | 353min | 2.4 step/s
#   step 50000 | loss: 1.1969 | 354min | 2.4 step/s
#   ── Epoch 4 | avg loss: 1.1969 | 354min ──
#   step 50200 | loss: 1.1954 | 356min | 2.4 step/s
#   step 50400 | loss: 1.1907 | 357min | 2.4 step/s
#   step 50600 | loss: 1.1876 | 359min | 2.4 step/s
#   step 50800 | loss: 1.1898 | 360min | 2.4 step/s
#   step 51000 | loss: 1.1887 | 361min | 2.4 step/s
#   step 51200 | loss: 1.1890 | 363min | 2.4 step/s
#   step 51400 | loss: 1.1886 | 364min | 2.4 step/s
#   step 51600 | loss: 1.1890 | 366min | 2.4 step/s
#   step 51800 | loss: 1.1898 | 367min | 2.4 step/s
#   step 52000 | loss: 1.1889 | 369min | 2.4 step/s
#   step 52200 | loss: 1.1892 | 370min | 2.4 step/s
#   step 52400 | loss: 1.1902 | 371min | 2.4 step/s
#   step 52600 | loss: 1.1899 | 373min | 2.4 step/s
#   step 52800 | loss: 1.1901 | 374min | 2.4 step/s
#   step 53000 | loss: 1.1894 | 375min | 2.4 step/s
#   step 53200 | loss: 1.1903 | 377min | 2.4 step/s
#   step 53400 | loss: 1.1898 | 378min | 2.4 step/s
#   step 53600 | loss: 1.1905 | 380min | 2.4 step/s
#   step 53800 | loss: 1.1902 | 381min | 2.4 step/s
#   step 54000 | loss: 1.1899 | 383min | 2.4 step/s
#   step 54200 | loss: 1.1903 | 384min | 2.4 step/s
#   step 54400 | loss: 1.1901 | 386min | 2.4 step/s
#   step 54600 | loss: 1.1899 | 387min | 2.4 step/s
#   step 54800 | loss: 1.1895 | 388min | 2.4 step/s
#   step 55000 | loss: 1.1894 | 390min | 2.4 step/s
#   step 55200 | loss: 1.1895 | 391min | 2.4 step/s
#   step 55400 | loss: 1.1893 | 393min | 2.4 step/s
#   step 55600 | loss: 1.1893 | 394min | 2.4 step/s
#   step 55800 | loss: 1.1894 | 395min | 2.4 step/s
#   step 56000 | loss: 1.1894 | 397min | 2.4 step/s
#   step 56200 | loss: 1.1894 | 398min | 2.4 step/s
#   step 56400 | loss: 1.1895 | 400min | 2.4 step/s
#   step 56600 | loss: 1.1891 | 401min | 2.4 step/s
#   step 56800 | loss: 1.1891 | 403min | 2.4 step/s
#   step 57000 | loss: 1.1889 | 404min | 2.4 step/s
#   step 57200 | loss: 1.1889 | 405min | 2.4 step/s
#   step 57400 | loss: 1.1888 | 407min | 2.4 step/s
#   step 57600 | loss: 1.1893 | 408min | 2.4 step/s
#   step 57800 | loss: 1.1893 | 410min | 2.4 step/s
#   step 58000 | loss: 1.1892 | 411min | 2.4 step/s
#   step 58200 | loss: 1.1892 | 413min | 2.4 step/s
#   step 58400 | loss: 1.1892 | 414min | 2.3 step/s
#   step 58600 | loss: 1.1888 | 416min | 2.3 step/s
#   step 58800 | loss: 1.1889 | 417min | 2.4 step/s
#   step 59000 | loss: 1.1889 | 418min | 2.3 step/s
#   step 59200 | loss: 1.1892 | 420min | 2.4 step/s
#   step 59400 | loss: 1.1890 | 421min | 2.3 step/s
#   step 59600 | loss: 1.1890 | 423min | 2.4 step/s
#   step 59800 | loss: 1.1889 | 424min | 2.4 step/s
#   step 60000 | loss: 1.1888 | 425min | 2.4 step/s
#   step 60200 | loss: 1.1888 | 427min | 2.4 step/s
#   step 60400 | loss: 1.1887 | 428min | 2.4 step/s
#   step 60600 | loss: 1.1887 | 430min | 2.4 step/s
#   step 60800 | loss: 1.1888 | 431min | 2.4 step/s
#   step 61000 | loss: 1.1888 | 432min | 2.4 step/s
#   step 61200 | loss: 1.1889 | 434min | 2.4 step/s
#   step 61400 | loss: 1.1890 | 435min | 2.4 step/s
#   step 61600 | loss: 1.1891 | 437min | 2.4 step/s
#   step 61800 | loss: 1.1893 | 438min | 2.4 step/s
#   step 62000 | loss: 1.1893 | 439min | 2.4 step/s
#   step 62200 | loss: 1.1894 | 441min | 2.4 step/s
#   step 62400 | loss: 1.1895 | 442min | 2.4 step/s
#   ── Epoch 5 | avg loss: 1.1895 | 443min ──
#
# ✅ Entraînement terminé
#    Steps: 62500 | Temps: 443 min
#    Steps/sec: 2.4
#    Best loss: 1.1875

# %%
# ═══════════════════════════════════════════════════════════
# TEST DE GÉNÉRATION
# ═══════════════════════════════════════════════════════════

model.eval()
print('Test de génération:')
test_prompts = ['le mot rapide', 'Paris est', 'la lumiere', 'le Soleil est']
for prompt in test_prompts:
    tokens = [w2i.get(w, 1) for w in prompt.lower().split()]
    input_ids = torch.tensor([2] + tokens, device=device)
    with torch.no_grad():
        logits = model(input_ids)
        next_token_logits = logits[-1]
        top5 = torch.topk(next_token_logits, 5)
        top_words = [i2w.get(idx.item(), '?') for idx in top5.indices]
        print(f'  "{prompt}" → {top_words}')
# Out:
# Test de génération:
#   "le mot rapide" → ['signifie', 'sluggish.', 'clever.', 'ou', 'est']
#   "Paris est" → ['un', 'connu', 'est', 'et', '=']
#   "la lumiere" → ['onde', 'science', 'langage', 'du', 'neutrons']
#   "le Soleil est" → ['signifie', 'connu', 'un', 'ou', 'sont']

# %%
# ═══════════════════════════════════════════════════════════
# COURBE DE LOSS
# ═══════════════════════════════════════════════════════════

import matplotlib.pyplot as plt
steps, losses = zip(*loss_history)
plt.figure(figsize=(10, 4))
plt.plot(steps, losses)
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('HWAT 4.7M — Training Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('loss_curve.png', dpi=100)
plt.show()
print('✅ Courbe sauvegardée: loss_curve.png')
# Out:
# ✅ Courbe sauvegardée: loss_curve.png
